# %%
import pandas as pd
import csv

# %%
df = pd.read_csv("places_data.csv")

# %%
df
# Out:
#                                        name                      website  \
# 0                     GNL | Desarrollos Web                          NaN
# 1                           Sirius Software                sirius.com.ar
# 2                                  MuleSoft                 mulesoft.com
# 3             IFSAR Soluciones Tecnológicas                          NaN
# 4                     Sistemas Tecnológicos  sistemastecnologicos.com.ar
# ..                                      ...                          ...
# 313     Control Ambiental Control de Plagas                          NaN
# 314                                 Sanidex                          NaN
# 315                   Robles desinfecciones  roblesdesinfecciones.com.ar
# 316                   MegaServicios Córdoba                          NaN
# 317  NMD desinfecciones Córdoba - Argentina                  webnode.com
#
#      reviews_score  reviews_amount         phone  \
# ...

# %%
# Count the number of rows where the 'website' column is NaN or includes ".negocio.site"
nan_or_contains_count = df['website'].isna().sum() + df['website'].str.contains('.negocio.site').sum()

# Print out the count
print(f"Number of rows where 'website' is NaN or contains '.negocio.site': {nan_or_contains_count}")
# Out:
# Number of rows where 'website' is NaN or contains '.negocio.site': 196
