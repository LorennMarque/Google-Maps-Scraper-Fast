# %%
import pandas as pd
import matplotlib as plt

# %%
data = pd.read_csv("places_data.csv")

# %%
data['have_website'] = data['website'].notna()

# %%
data['have_website'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='have_website'>

# %%
data['reviews_score'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='reviews_score'>

# %%
data[data['have_website'] == 0][['name', 'googlemaps_link', 'phone']].to_csv('no_website_places.csv', index=False)
